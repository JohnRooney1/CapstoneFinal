# %%
# Group the data by country and calculate the average AQI value
average_aqi_by_country = data.groupby('country_name')['aqi_value'].mean()

# Sort the countries by average AQI value in descending order and select the top 10
top_10_countries = average_aqi_by_country.sort_values(ascending=False).head(10)

# Create a bar chart of average AQI values for the top 10 countries
plt.figure(figsize=(10, 6))
top_10_countries.plot(kind='bar', color='skyblue')
plt.title('Top 10 Countries with Highest Average AQI Values')
plt.xlabel('Country')
plt.ylabel('Average AQI Value')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv("global_air_pollution_data.csv")

# Bar chart showing the distribution of AQI categories
plt.figure(figsize=(10, 6))
data['aqi_category'].value_counts().plot(kind='bar', color='orange')
plt.title('Distribution of AQI Categories')
plt.xlabel('AQI Category')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Box plot showing the distribution of AQI values by AQI category
plt.figure(figsize=(10, 6))
data.boxplot(column='aqi_value', by='aqi_category', figsize=(10, 6))
plt.title('Distribution of AQI Values by AQI Category')
plt.xlabel('AQI Category')
plt.ylabel('AQI Value')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Histogram showing the distribution of PM2.5 AQI values
plt.figure(figsize=(10, 6))
plt.hist(data['pm2.5_aqi_value'], bins=20, color='purple', alpha=0.7)
plt.title('Distribution of PM2.5 AQI Values')
plt.xlabel('PM2.5 AQI Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Heatmap showing the correlation between different pollutants
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.heatmap(data[[ 'ozone_aqi_value', 'no2_aqi_value', 'pm2.5_aqi_value']].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation between Different Pollutants')
plt.tight_layout()
plt.show()

# %%
# Load the dataset
data = pd.read_csv("global_air_pollution_data.csv")

# Calculate the number of months
num_months = 12

# Create a synthetic month column based on row number
data['month'] = (data.index % num_months) + 1

# Calculate the average AQI values for each month
average_aqi_by_month = data.groupby('month')['aqi_value'].mean()

# Create a line plot of average AQI values by month
plt.figure(figsize=(10, 6))
average_aqi_by_month.plot(marker='o', color='green')
plt.title('Average AQI Values by Month')
plt.xlabel('Month')
plt.ylabel('Average AQI Value')
plt.xticks(ticks=range(1, num_months + 1), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Group the data by AQI category and calculate the average AQI value
average_aqi_by_category = data.groupby('aqi_category')['aqi_value'].mean()

# Create a bar chart of average AQI values by AQI category
plt.figure(figsize=(10, 6))
average_aqi_by_category.plot(kind='bar', color='skyblue')
plt.title('Average AQI Values by AQI Category')
plt.xlabel('AQI Category')
plt.ylabel('Average AQI Value')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
